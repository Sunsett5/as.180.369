# %% [markdown]
# # A Heterogeneous-agents Model of Endogeneous Growth

# %% [markdown]
# ## Abstract
#
# The study extends the scope of endogenous growth model with heterogeneous-agents models. While the concept of endogenous growth driven by the R&D sector has been extensively studied, the majority of pioneering works, such as {cite:t}`Romer_1990`, have been grounded in the assumption of homogeneous research products. Building on recent contributions by {cite:t}`Dosi_Roventini_Russo_2017`, which introduced heterogeneity into the production and R&D process, this paper introduce overlooked heterogeneity in the size of R&D expense and distinct preferences for engaging in innovative research as opposed to imitating other firms in the same industry. Models' parameters will be adjusted to study the underlying uncertainty of innovative R&D and the environment in which innovation thrives in an international market setting. Through Monte Carlo simulations, this research explores the implications of heterogeneity within these various agents on innovation, long-term productivity growth, and convergence. By addressing this important research gap, we aim to shed light on the nuanced dynamics that govern economic growth and identify possible sources to divergence observed in cross-country empirical studies.

# %% [markdown]
# ## Introduction
#
# {cite:t}`Romer_1990`'s endogenous growth model introduces new ways of looking at growth in total factor productivity through technology. In his model, research and development (R&D) as an alternative sector which utilizes labor and capital resources to produce knowledge, a partially excludable good. Creating knowledge requires diverting human and capital stocks away from consumer goods and capital production. The economy in turn trades current consumption for future productivity growth. Knowledge, however, possesses a unique attribute separating it from consumer and capital goods – it is only partially excludable due to intellectual property laws. Other agents can freely utilize this spillover knowledge to advance their own research, not infringing on intellectual property rights. This situation results in positive externalities that contribute to economic growth. Nonetheless, profit-maximizing agents, driven solely by private benefits, often disregard these broader social advantages. This leads to two noteworthy consequences: First, investments in capital are below optimal level, and the employment of researchers remains Pareto inefficient ({cite:t}`Fine_2000`). Second, developing countries can capitalize on the existing knowledge created by more technologically-advanced nations without the need to invest significantly in their research and development.
#
# This advantage enables developing countries to catch up with their technologically advanced counterparts. In theory, advanced economies operating at the technological frontier should experience a slowdown in growth, ultimately closing the gap between countries with varying levels of technological advancement. This concept, often referred to as "convergence" in economic growth, has, however, not found strong empirical support. In {cite:t}`Johnson_Papageorgiou_2020`'s comprehensive survey of convergence literature spanning the last five decades, the income gap between poorer and richer countries has shown more persistence than conventional theory would suggest.
#
# In response to this challenge, the term of "conditional convergence" emerged, asserting that two countries will reach the same steady state of economic growth only if their internal factors supporting economic growth are aligned. Several studies have sought to identify these critical internal factors. For instance, {cite:t}`Barro_Sala-i-Martin_2014` examined a panel of 88 countries, investigating 67 explanatory variables frequently utilized in empirical growth literature. These variables encompass factors like life expectancy, fertility rates, rule of law indices, education, investment ratios, government expenditure ratios, openness, terms-of-trade, inflation, democracy, and more. The significance of each variable is subject to the chosen functional forms and the set of variables under consideration {cite:t}`Barro_2015`.
#
# To bridge the gap between endogenous growth models and these empirical observations, {cite:t}`Dosi_Roventini_Russo_2017` introduced a multi-country, multi-industry agent-based model. This model incorporates heterogeneous firms from different countries and industries, engaging in competitive international trade. In contrast to {cite:t}`Romer_1990`, the multi-sectoral framework facilitates the observation of structural changes. Additionally, the open economy feature illustrates how countries exploit technology gaps, shedding light on whether convergence, divergence, or polarization into low- and high-growth economies occurs.
#
# {cite:t}`Dosi_Roventini_Russo_2017` make valuable contributions to endogenous growth theories, introducing heterogeneity among firms and the skills of workers. Yet, one aspect that has remained relatively unexplored is the concious choice between innovation and imitation R&D. Firms must assess whether a specific R&D innovation is going to be successful, reflecting the underlying uncertainty of operating at the frontier of technology. In contrast, firms could invest in R&D imitation project instead, which relies on the positive externality nature of knowledge. As the profitability of a certain R&D project depends greatly on the actions other firms are taking, the models can be best modeled with heterogenous agents making decisions based on their distinct stock of capital, market share, current productivity, etc. compared to other firms in international markets. The choices made by these agents are also influenced by macroeconomic variables, such as policy interest rates, world interest rates, inflation, political stability, and market volatility.
#
# This research employs Monte Carlo simulations to explore the implications of heterogeneity within these diverse agents on innovation, long-term productivity growth, and convergence. By introducing this new dimension of factors that afftect innovation tendency, we aim to illuminate the nuanced dynamics underlying economic growth and identify potential sources for the observed divergence in cross-country empirical studies.

# %% [markdown]
# ## Literature Review
#
# Given the same level of labor and capital, modern economies can produce much more efficiently than their historical counterparts due to an increase in total factor productivity (TFP). Economists in the 1950s attributed most of this growth to technological advancement ({cite:t}`Schultz_Abramovitz_1957`; {cite:t}`Kendrick_1956`; {cite:t}`Solow_1956`). Despite acknowledging technology as primary driver of long-run growth, early economic models continued to treat it as an exogenous factor, requiring empirical observation. However, in contrast to these earlier approaches, more recent models, notably {cite:t}`Romer_1990`'s endogenous technological change model, have internalized technology as a consequence of profit-maximizing economic agents.
#
# On the topic of endogenous growth, the influence of {cite:t}`Romer_1990` cannot be overstated. His paper formalized the partial excludability of knowledge. Both simple observation and economic principles support this quality of knowledge as a good. Practical examples include patents, copyright, trade secrets, industrial design rights, database rights, etc. which are protected by intellectual property laws. This protection excludes other firms from directly utilizing the research product but not prevents them to learn from the knowledge that might be made public and create new innovations of their own. On the economic side, {cite:t}`Romer_1990` explains that without some degree of excludablity, firms will not be incentived to engage in research in the first place. This is particularly critical in perfectly competitive market with identical firms because they cannot afford to incur cost higher than the market marginal cost of production. Had one firm engaged in research, they would lose profitability in the short run and gain no competitive edge in the long run without excludability.
#
# The concern of suboptimal level of R&D still holds even in partial excludability case. {cite:t}`Arrow_1962` and {cite:t}`Romer_1986` demonstrates that decentralized choices can lead to suboptimal level of research because private agents do not account for spillovers of knowledge. This problem leads to a new branch of models such as in {cite:t}`Barro_1990` which focuses on whether government spending can help fix market failure. ~~In order to test model robustness, empirical research on conditional convergence are conducted. {cite:t}`Barro_2015`.~~
#
# Recent theoretical research began to put more focus on heterogeneity of economic agents. {cite:t}`Arawatari_Hori_Mino_2023` proposed a heterogeneous-agents model that takes into account labor market heterogeneity. In his model, household agents exhibit varying levels of entrepreneurial ability, affecting their inclination to engage in innovation and their compensation. {cite:t}`Arawatari_Hori_Mino_2023`'s model consists of one closed economy and is calibrated to observe the impact of government expenditures on economic growth based on U.S. data.
#
# {cite:t}`Dosi_Roventini_Russo_2017` presents another model which investigates the role of the international market in technology accumulation through a heterogenous-agent model with imperfect competition. Instead of modelling research as a separate sector as in {cite:t}`Romer_1990`, he assumed that research occurs inside each consumption-good firm. The specification implies that partial excludability must exist in the form of market power for consumption goods. Nonetheless, {cite:t}`Romer_1990` stated that such distinction is inconsequential to the result observed. {cite:t}`Dosi_Roventini_Russo_2017`'s model also explicit identify the difference between innovation and imitation as two separate R&D choices; however, he assumes the ratio of of R&D spent on each category to be fixed and homogenous among all agents.
#
# I view this assumption as a significant simplification because firms may have heterogenous preferences on innovation and imitation. Since innovation involves high uncertainty, some might be drawn to the untapped potential, while others may choose to adopt existing technology from other firms instead. {source} Thus, this paper will provide an extension to {cite:t}`Dosi_Roventini_Russo_2017` through heterogenous R&D preference. In addition, many simplifying assumptions will be lifted and substituted with market-based mechanism.

# %% [markdown]
# ## Methodology
#
# The foundation of the model presented here is based primarily on a multi-country, multi-industry agent-based model by {cite:t}`Dosi_Roventini_Russo_2017`, which is a derivative of Keynes+Schumpeter family of models in {cite:t}`Dosi_Fagiolo_Napoletano_Roventini_2013`. The model consists of $N$ economies (indexed by $i$) and $M$ industries (indexed by $h$), each with a representative capital-good sector. Finally, there are $S$ firms per industry per country. Every firm exhibit heterogeneity and operates imperfectly competitive in both domestically and internationally. Technological progress is modeled as labor augmenting and is Harrod Neutral. Technological growth can occur either due to innovation of new technology or imitation from other firms in the same industry. The latter acknowledges the partial-excludability of knowledge stock discussed in {cite:t}`Romer_1990` and allows for the possibility of convergence. In contrast to {cite:t}`Dosi_Roventini_Russo_2017` with infite supply of labor, I choose to restrict labor to a growth rate $n$. This approach is in line with both {cite:t}`Jones_1995`'s finding that the long-run growth rate is limited by exogenous population growth and {cite:t}`Romer_1990`'s related conclusion based on human capital growth.
#
# ### Timeline of the events
# 1. At the start of time step $t$, each firm $j$ plans its spending on wage expense, capital cost based on both past and expectation of future sales. The representative capital-good sector hires labor at the same national wage rate as consumption-good sector and produces capital as demanded by consumption-good firms.
# 2. The remaining budget is spent on R&D operation either through innovation or imitation. If the operation is successful, the firm labor productivity will increase at time step $t+1$.
# 3. Nominal wage and nominal exchange rates are set at national level.
# 4. Workers spend their wage income on consumption-good in an imperfectly competitive international market. The real exchange rate of each country and its firms' monopoly power evolve based on their price competitiveness.
# 5. Entry and exit of firms are determined by their monopoly power.
#
# At the end of each time period, national aggregate variables are accumulated across industries and firms. The following sections will discuss the model framework in details.

# %% [markdown]
# ### The Model
#
# A common feature of economic growth model is an assumption of constant or increasing returns to factors of production. In {cite:t}`Lucas_1988` and {cite:t}`Rebelo_1991`, the constant returns to scale applies to both rival (labor $L$ and capital $K$) and nonrival (technology $A$) factors. Here, we follow {cite:t}`Romer_1990`'s approach of keeping constant returns only to capital and labor. This choice is motivated by standard replication argument. Therefore, the Cobb-Douglas production function is:
#
# \begin{align}
# Q &= A_0 L^\alpha K^{1-\alpha}
# \end{align}
#
# Consistent with empirical evidence {cite:t}`Kaldor_1957` {cite:t}`Dosi_Pavitt_Soete_1993`, the capital-output ratio is constant ($\frac{K}{Q}=B$). Consequently, whenever firms change labor input, capital needs to be adjusted according'y to satisfy this restriction. The simplified production function becomes:
#
# \begin{align}
# Q &= A_0 L^\alpha (BQ)^{1-\alpha}\\
# Q^\alpha &= A_0 B^{1-\alpha} L^\alpha\\
# Q &= A_0^{1/\alpha} B^{(1-\alpha)/\alpha} L\\
# Q &= AL\\
# K &= BAL
# \end{align}
#
# where $A = A_0^{1/\alpha} B^{(1-\alpha)/\alpha}$ is the modified total factor productivity.
#
# **Step 1 Consumption-Good Production:**
#
# Firms decide the level of production by choosing the amount of labor employed. Since firms have to maintain constant capital-output ratio, they need to purchase more capital to expand their capacity ($Ie$) and to replace depreciated capital ($Ir$). The expansion investment is the difference between the desired ($K(t)$) level and the existing stock from the previous year ($K(t-1)$). The replacement investment is $\delta K$ where $\delta$ is the depreciation rate.
#
# The capital stock evolves according to:
#
# \begin{align}
# K^i_{j,h}(t) = K^i_{j,h}(t-1) + Ie^i_{j,h}(t)
# \end{align}
#
# For a firm $j$ that chooses to employ $Lc^i_{j,h}$ at time $t$, it needs to purchase more capital equal to the amount:
#
# \begin{align}
# I^i_{j,h}(t) &= Ie^i_{j,h}(t) + Ir^i_{j,h}(t)\\
# I^i_{j,h}(t) &= K^i_{j,h}(t)- K^i_{j,h}(t-1)+ \delta K^i_{j,h}(t)\\
# I^i_{j,h}(t) &= (1+\delta)BA^i_{j,h} Lc^i_{j,h}(t)- K^i_{j,h}(t-1)\\
# \end{align}
#
# For simplicity, I follow {cite:t}`Dosi_Roventini_Russo_2017`'s assumption that the total factor productivity of the capital sector tracks the national average productivity in the consumption-good sector $\overline{A^i}(t) = \sum_{h=1}^M \sum_{j=1}^S A^i_{j,h}$.
#
# Thus, the  corresponding labor employed to produce $I^i_{j,h}(t)$ quantity of capital for firm  $j$ is:
#
# \begin{align}
# Lk^i_{j,h}(t) &= \frac{I^i_{j,h}(t)}{\overline{A^i}(t)}
# \end{align}
#
# The national employment in the consumption good sector amounts to $Lc^i=\sum_{h=1}^M \sum_{j=1}^S Lc^i_{j,h}$
#
# The national investment is $I^i = \sum_{h=1}^M \sum_{j=1}^S I^i_{j,h}$ .To supply consumtion-good firms with $I(t) =$ capital, the resentative capital sector must employ labor ($L_k$) from the same labor market.
#
# \begin{align}
# Lk^i(t) &= \frac{I^i(t)}{\overline{A^i}(t)}
# \end{align}
#
# The national labor employed in economy $i$ is then equal to $L^i(t) = Lc^i(t) + Lk^i(t)$ which is subjected to an exogenous growth rate $n$. The real market wage is determined competitively based on the marginal productivity of labor of each firm $MPL$. The $MPL$ in this context differs from the usual definition because firms in this model are assumed to maintain constant capital-output ratio. If a firm wants to produce more than its capacity, its $MPLe$ is relative to the sum of labor it directly and those employed in the capital sector for a corresponding amount of capital needed.
#
# \begin{align}
# MPLe^i_{j,h}(t) &= \frac{d \; Q^i_{j,h}(t)}{d \; Lc+Lk}\\
# MPLe^i_{j,h}(t) &= \biggl(\frac{d \; Q^i_{j,h}(t)}{d \; Lc}\biggr) \biggl(\frac{d \; Lc}{d \; Lc + Lk}\biggr)\\
# MPLe^i_{j,h}(t) &= \biggl(\frac{d \; A^i_{j,h}(t) Lc}{d \; Lc}\biggr) \biggl(\frac{d \; Lc + Lk}{d \; Lc}\biggr)^{-1}\\
# MPLe^i_{j,h}(t) &= \Bigl(A^i_{j,h}(t)\Bigr) \biggl(1+\frac{d \; Lk}{d \; Lc}\biggr)^{-1}\\
# MPLe^i_{j,h}(t) &= \Bigl(A^i_{j,h}(t)\Bigr) \biggl(1+\frac{1}{\overline{A^i}(t)}\frac{d \; I^i_{j,h}(t)}{d \; Lc}\biggr)^{-1}\\
# MPLe^i_{j,h}(t) &= \Bigl(A^i_{j,h}(t)\Bigr) \biggl(1+\frac{1}{\overline{A^i}(t)}\bigl(1+\delta)BA^i_{j,h}(t)\bigr)\biggr)^{-1}\\
# MPLe^i_{j,h}(t) &= \biggl(\frac{1}{A^i_{j,h}(t)}+\frac{(1+\delta)B}{\overline{A^i}(t)}\biggr)^{-1}\\
# \end{align}
#
# On the other hand, if a firm has excess capacity at a given level of output, its $MPL$ is simply relative to the labor employed to fully utilize existing capital stock.
#
# \begin{align}
# MPLs^i_{j,h}(t) &= \biggl(\frac{d \; Q^i_{j,h}(t)}{d \; Lc}\biggr)\\
# MPLs^i_{j,h}(t) &= A^i_{j,h}(t)
# \end{align}
#
# The $MPL$ for firms with excess capital (less depreciation) and vacant positions will be much higher than those looking to expand its production ($MPLs \gg MPLe$), so labor will be drawn to fill those vacant position first. For simplicity, it is logical to assume that every firm will fill all vacant positions first, then the remaining labor supply will be employed in roles with the highest $MPLe$ first, followed by positions with progressively lower $MPLe$.
#
# The decision to employ workers over the current production capacity depends on the marginal revenue product ($MRP$) which is a product of $MPLe$ and price ($P$). In this paper, I use a power inverse demand function.
#
# \begin{align}
# MRP^i_{j,h}(t) &= MPLe^i_{j,h}(t)P^i_{j,h}(t)\\
# MRP^i_{j,h}(t) &= MPLe^i_{j,h}(t)H^i_{j,h}(t)[Q^i_{j,h}(t)+In^i_{j,h}(t)]^{-a}
# \end{align}
#
# where $H^i_{j,h}(t)$ is a constant satisfying the long-run restriction that if a firm set price equal to the average industry price ($P^i_{j,h}(t)=\overline{P}^i_{h}(t-1)$), then its market share would be constant. $In^i_{j,h}(t)$ is the accumulated inventory from previous years. Firms are allowed to produce more than they can sell in the short run; however, the $MRP^i_{j,h}(t)$ penaltizes such decision through the inventory term. In the long run, firms' stock of inventory will be close to zero most of the time.
#
# \begin{align}
# L^i(t) &= Lc^i + Lk^i\\
# L^i(t) &= \sum_{h=1}^M \sum_{j=1}^S Lc^i_{j,h} + \frac{I^i(t)}{\overline{A^i}(t)}
# \end{align}

# %% [markdown]
# **Step 2: Private Research and Development**
#
# The remaining profit of firm $j$ is then used to finance R&D operation. In this model, I assume that each firm's total expense is limited to its revenue each year. An inclusion of market-based intertemporal allocation of resources is left for future work.
#
# ... about future expectation
#
# Since the formulation of expectation in hetereogenous agents model can be complicated to model and require numerous assumptions, this paper instead attempt to capture the effectiveness of each R&D choice through numerical simulation. Each firm is assigned a fixed proportion ($\lambda^i_{j,h}$) of RD spent on innovation ($IN$) drawn unifromly from $U(0,1)$ at the start of simulation. Consequently, the rest is spent on imitation ($IM$).
#
# \begin{align}
# IN^i_{j,h} &= \lambda^i_{j,h} RD^i_{j,h}\\
# IM^i_{j,h} &= (1-\lambda^i_{j,h}) RD^i_{j,h}
# \end{align}
#
# In line with {cite:t}`Dosi_Roventini_Russo_2017`, the innovation and imitation processes are modeled as two-step stochastic process. Firstly, the success of innovation or imitation is drawn from $Bern(\theta)$. The probabilities of success ($\theta \text{in}, \theta \text{in}$) are positively related to R&D expenditure but limited to an upper ceiling $\theta _{max}$. The success rate also depends on firms' search capabilities ($\xi_{1,2} > 0$)
#
# \begin{align}
# \theta \text{in}^i_{j,h}(t) &= \min\Bigl\{\theta _{max}, 1-e^{-\xi _1 IN^i_{j,h}(t)}\Bigr\}\\
# \theta \text{im}^i_{j,h}(t) &= \min\Bigl\{\theta _{max}, 1-e^{-\xi _2 IM^i_{j,h}(t)}\Bigr\}
# \end{align}
#
# A firm with successful innovation learns new production technique at time $t+1$. The productivity of such technology ($A\text{in}$) is uncertain in nature:
#
# \begin{align}
# A\text{in}^i_{j,h}(t+1) = A^i_{j,h}(t) (1+x^i_{j,h}(t))
# \end{align}
#
# where $x$ is drawn from $Beta(\alpha _1,\beta _1)$ with support $[\underline{x}_1,\overline{x}_1]$. Since the acquire technology may or may not improve current productivity, I set $\underline{x}_1 \in [-1,0]$ and $\overline{x}_1 \in [0,1]$.
#
# A firm with successful imitation will randomly copy another firm productivity $A^i_{j,h}(t)$. As in {cite:t}`Dosi_Roventini_Russo_2017`, the probability to imitate a particular is inversely proportional to the euclidian distance between ther productivity. Firms will be more likely to learn the technology from a firm with closer level of technology to them. The imitation processes occur both domestically and internationally, although international imitation incurs a multiplicative penalty $\epsilon > 1$ to the euclidian distance between their productivity. The challenge of imitating foreign techniques are discussed in {cite:t}`Abramovitz_1986` and {cite:t}`Fagerberg_Godinho_2006`
#
# Finally, the firm compares its newly acquired techniques from innovation or imitation with its existing techniques and choose to adopt the one with highest productivity.
#
# \begin{align}
# A^i_{j,h}(t+1)=\max\Bigl\{A^i_{j,h}(t),A\text{in}^i_{j,h}(t+1),A\text{im}^i_{j,h}(t+1)\Bigr\}
# \end{align}

# %% [markdown]
# **Step 3: Dynamics of International Market**
#
# The following section follows {cite:t}`Dosi_Roventini_Russo_2017`'s market dynamics model closely, but the Schumpeterian exit and entry dynamics is adjusted to allow for dynamics of heterogeneity in R&D spending.
#
# The fundamental assumption is imperfect competition in international market due to differentiated goods in the same industry. The demand of residents in country $k$ for each firm's good $j$ is characterized by the firm's competitiveness $E^{i,k}_{j,h}$. In line with negative demand curve for imperfect competition, competitiveness $E^{i,k}_{j,h}$ is inversely related to its domestic price ($p^{i}_{j,h}$) times nominal exchange rate ($e^{i,k}$ (For goods domestically, $e^{i,k} = 1$). Furthermore, goods sold internationally also incur a cost penalty ($1+\tau$), reflacting transport expense and costs required to penetrade the market.
#
# \begin{align}
# E^{i,k}_{j,h}(t) &= \frac{1}{p^{i}_{j,h}(t) \; e^{i,k}(t) \; (1+\tau)}
# \end{align}
#
# On a technical note, the exchange rate matrix is constructed from $n \times 1$ exchange rate vector to ensure that triangular arbitrage does not exist. The exchange rate between economy $i$ and $k$ ($e^{i,k}$) is the quotient of $e^i / e^k$. The exchange rate vector itself evolves as demand for goods from that country changes—according to the equation below with a stochastic noise:
#
# \begin{align}
# e^i(t) = e^i(t-1)\Bigl(1+ \gamma \frac{TB^i(t-1)}{\hat{Y(t-1)}} + u^i(t)\Bigr)
# \end{align}
#
# Where $TB$ is the country's trade balance and $\hat Y$ is the world GDP, both of which will be formally derived in the next section.
#
# In an industry $h$ of economy $k$, the average competitiveness weighted by monopoly power $(f^{i,k}_{j,h})$ is:
#
# \begin{align}
# \overline{E}^k_h(t)=\sum_{i=1}^N \sum_{j=1}^S f^{i,k}_{j,h}(t-1) E^{i,k}_{j,h}(t)
# \end{align}
#
# The deviation of a firm's competitiveness from the average value $\overline{E}^k_h(t)$ determine its dynamics of monopoly through a quasi-replication process.
#
# \begin{align}
# f^{i,k}_{j,h}(t) = f^{i,k}_{j,h}(t-1)\Biggl(1+\chi \frac{E^{i,k}_{j,h}(t)-\overline{E}^k_h(t)}{\overline{E}^k_h(t)}\Biggr)
# \end{align}
#
# with $\chi > 0$. Firms with competitive pricing will gain progressively higher market share, and consequently can charge higher price. This in turn decreases its competitiveness to the average level in the long run. Therefore, this specification guarantees that the competitiveness of any particular firm is bounded.
#
# We define the market share of firm $j$ operating in the global market as its average on every country of operation: $f^i_{j,h}(t) = \frac{1}{N} \sum_{k=1}^N f^{i,k}_{j,h}(t)$

# %% [markdown]
# ## Results
# In order to observe the dynamics of technological innovation and the degree of convergence, each firm is given the same level of productivity at the start, while their proportion of profits reinvested on R&D ($\rho^i_{j,h}$) and proportion of RD spent on innovation ($\lambda^i_{j,h}$) are drawn unifromly from $U(0,1)$ at the start of simulation. After each timestep, their productivity evolve corresponding to how much was invested into R&D on the previous timestep. At the end of each cycle, total profits (net R&D spending) are calculated, and the firms will bottom 10 percentile profits made are eliminated the market. The empty spots are then repopulated by uniformly sampling from surviving firms.
#
# Below I present the result of Monte Carlo simulations.

# %% [markdown]
# ### Dynamics of Productivity
#
# {ref}`A_trend_20_40_40_11_1_0.2-fig` and {ref}`A_trend_20_40_40_11_0.2_1-fig` show the dynamics of firm productivity in 10 cycles of market elimination. In an environment where innovation dominates imitation in terms of effectiveness per dollar spent [{ref}`A_survive_20_40_40_11_1_0.2-fig`], firms seem to exhibit stronger degree of divergence than [{ref}`A_survive_20_40_40_11_0.2_1-fig`]. This is as expected from the model's specification, since firms intrinsically face higher difficultly in imitating other firms.
#
# ```{figure} images/A_trend_20_40_40_11_1_0.2.jpg
# ---
# height: 300px
# name: A_trend_20_40_40_11_1_0.2-fig
# ---
# Productivity exhibit divergence behavior $(\xi_{IN} = 1 \quad \xi_{IM} = 0.2)$
# ```
# ```{figure} images/A_trend_20_40_40_11_0.2_1.jpg
# ---
# height: 300px
# name: A_trend_20_40_40_11_0.2_1-fig
# ---
# Productivity exhibit divergence behavior $(\xi_{IN} = 0.2 \quad \xi_{IM} = 1)$
# ```

# %% [markdown]
# ### Firms' search capabilities
# Each firm is given identical search capabilities which determine the effectiveness of innovation and imitation process. {ref}`profits_20_40_40_11_1_0.2-fig` and {ref}`profits_20_40_40_11_0.2_1-fig` show the posterior distribution of firms' profits. As anticipated from the elimination process, surviving firms all have similar level of profits compared to the pior distribution of profits. This represents an equilibrium where each firm is making optimal decisions given the decisions of other firms in the market.
#
# ```{figure} images/profits_20_40_40_11_1_0.2.jpg
# ---
# height: 300px
# name: profits_20_40_40_11_1_0.2-fig
# ---
# Posterior Distribution of Profits
# $\xi_{IN} = 1 \quad \xi_{IM} = 1$
# ```
#
# ```{figure} images/profits_20_40_40_11_0.2_1.jpg
# ---
# height: 300px
# name: profits_20_40_40_11_0.2_1-fig
# ---
# Posterior Distibution of Profits
# $\xi_{IN} = 0.2 \quad \xi_{IM} = 1$
# ```
#
# {ref}`A_survive_20_40_40_11_1_0.2-fig` and {ref}`A_survive_20_40_40_11_0.2_1-fig` show the posterior distribution of firms' propensity to research ($\rho^i_{j,h}$) and propensity to innovate ($\lambda^i_{j,h}$) after 10 cycles of market elimination.
#
#
# ```{figure} images/A_survive_20_40_40_11_1_0.2.jpg
# ---
# height: 300px
# name: A_survive_20_40_40_11_1_0.2-fig
# ---
# $\xi_{IN} = 1 \quad \xi_{IM} = 0.2$
# ```
#
# ```{figure} images/A_survive_20_40_40_11_0.2_1.jpg
# ---
# height: 300px
# name: A_survive_20_40_40_11_0.2_1-fig
# ---
# $\xi_{IN} = 0.2 \quad \xi_{IM} = 1$
# ```
#
# In an innovation dominant environment [{ref}`A_survive_20_40_40_11_1_0.2-fig`], surviving firms tend to stay in the region $\lambda$ > $\rho$ with large accumulation of firms settling along the critical line $\lambda$ = $\rho$. On the contrary, when imitation dominates imitation [{ref}`A_survive_20_40_40_11_0.2_1-fig`], firms are also able to settle in the region close but below the critical line $\lambda$ = $\rho$.

# %% [markdown]
# ```{bibliography}
# ```
